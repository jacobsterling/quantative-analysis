# %%
import ccxt
import pandas as pd

# Initialize the KuCoin Futures exchange
exchange = ccxt.kucoinfutures()

# Fetch all markets
markets = pd.DataFrame(exchange.load_markets()).transpose()

markets.head()
# Out:
#                        id lowercaseId          symbol  base quote settle  \
# BTC/USDT:USDT    XBTUSDTM        None   BTC/USDT:USDT   BTC  USDT   USDT
# ETH/USDT:USDT    ETHUSDTM        None   ETH/USDT:USDT   ETH  USDT   USDT
# SOL/USDT:USDT    SOLUSDTM        None   SOL/USDT:USDT   SOL  USDT   USDT
# WIF/USDT:USDT    WIFUSDTM        None   WIF/USDT:USDT   WIF  USDT   USDT
# PEPE/USDT:USDT  PEPEUSDTM        None  PEPE/USDT:USDT  PEPE  USDT   USDT
#
#                baseId quoteId settleId  type  ... expiryDatetime strike  \
# BTC/USDT:USDT     XBT    USDT     USDT  swap  ...           None   None
# ETH/USDT:USDT     ETH    USDT     USDT  swap  ...           None   None
# SOL/USDT:USDT     SOL    USDT     USDT  swap  ...           None   None
# WIF/USDT:USDT     WIF    USDT     USDT  swap  ...           None   None
# PEPE/USDT:USDT   PEPE    USDT     USDT  swap  ...           None   None
#
#                optionType                                          precision  \
# ...

# %%
markets[markets['type'] == 'swap']
# Out:
#                        id lowercaseId          symbol  base quote settle  \
# BTC/USDT:USDT    XBTUSDTM        None   BTC/USDT:USDT   BTC  USDT   USDT
# ETH/USDT:USDT    ETHUSDTM        None   ETH/USDT:USDT   ETH  USDT   USDT
# SOL/USDT:USDT    SOLUSDTM        None   SOL/USDT:USDT   SOL  USDT   USDT
# WIF/USDT:USDT    WIFUSDTM        None   WIF/USDT:USDT   WIF  USDT   USDT
# PEPE/USDT:USDT  PEPEUSDTM        None  PEPE/USDT:USDT  PEPE  USDT   USDT
# ...                   ...         ...             ...   ...   ...    ...
# ZEUS/USDT:USDT  ZEUSUSDTM        None  ZEUS/USDT:USDT  ZEUS  USDT   USDT
# ZIL/USDT:USDT    ZILUSDTM        None   ZIL/USDT:USDT   ZIL  USDT   USDT
# ZK/USDT:USDT      ZKUSDTM        None    ZK/USDT:USDT    ZK  USDT   USDT
# ZRO/USDT:USDT    ZROUSDTM        None   ZRO/USDT:USDT   ZRO  USDT   USDT
# ZRX/USDT:USDT    ZRXUSDTM        None   ZRX/USDT:USDT   ZRX  USDT   USDT
#
#                baseId quoteId settleId  type  ... expiryDatetime strike  \
# ...

# %%
# Print total number of available futures pairs
print(f"\nTotal number of futures pairs: {len(df)}")

# Print symbols only
print("\nAvailable symbols:")
print(df['Symbol'].tolist())
