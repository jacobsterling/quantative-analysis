# %%
from models.exectution.order_flow_analysis import OrderFlowAnalysis

client = OrderFlowAnalysis(
    "XBTUSDTM",
    load_order_book=True,
)

client.orderbook
# Out:
# F:\quantative-analysis\models\exectution\strategy_base.py:71: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   self._ohlcv = concat([self._ohlcv, data], ignore_index=False)
# F:\quantative-analysis\models\exectution\strategy_base.py:71: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self._ohlcv = concat([self._ohlcv, data], ignore_index=False)
#      bid_price  bid_quantity  ask_price  ask_quantity    symbol  \
# 0      56019.2        1284.0    56019.3        2228.0  XBTUSDTM
# ...

# %%
client
# Out:
#   File "C:\Users\j10st\AppData\Local\Temp\ipykernel_21256\3667280310.py", line 1
#     from talib.
#                ^
# SyntaxError: invalid syntax

# %%
client.populate_entry_signals()

client.orderbook[client.orderbook["entry_signal"]]
# Out:
# Empty DataFrame
# Columns: [bid_price, bid_quantity, ask_price, ask_quantity, symbol, timestamp, nonce, spread, order_imbalance, cumulative_order_flow, entry_signal, exit_signal]
# Index: []

# %%
client.ohlcv[client.ohlcv["trade_side"] != ""]
# Out:
#                         open     high      low    close  volume          vwap  \
# 2024-09-05 04:00:00  57128.5  57128.5  57095.9  57103.4  5414.0  57109.266667
# 2024-09-05 04:05:00  57134.8  57134.8  57100.6  57100.6  1059.0  57119.424443
# 2024-09-05 04:09:00  57182.2  57228.1  57178.6  57228.1  5452.0  57134.032836
# 2024-09-05 04:14:00  57224.5  57258.6  57224.5  57255.1  2618.0  57159.300246
# 2024-09-05 04:22:00  57194.5  57194.5  57164.0  57164.0  1128.0  57186.405534
# ...                      ...      ...      ...      ...     ...           ...
# 2024-09-05 07:15:00  57155.4  57195.3  57132.0  57148.1  3846.0  56978.817327
# 2024-09-05 07:16:00  57155.3  57175.3  57133.8  57140.1  2137.0  56979.142434
# 2024-09-05 07:17:00  57149.4  57149.4  57100.9  57122.5  3128.0  56979.545372
# 2024-09-05 07:18:00  57122.5  57136.3  57100.7  57105.3  3400.0  56979.950228
# 2024-09-05 07:19:00  57105.4  57184.4  57105.4  57164.6  6517.0  56980.933739
#
# ...
